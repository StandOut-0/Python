# %%
pip install pykrx
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 125.5/125.5 kB 7.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 52.1/52.1 kB ? eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pykrx import stock

# %%
stock.get_market_ohlcv_by_date("20210101", "20221231", "005930")
# Out:
#                시가     고가     저가     종가       거래량           거래대금   등락률
# 날짜
# 2021-01-04  81000  84400  80200  83000  38655276  3185356823460  2.47
# 2021-01-05  81600  83900  81600  83900  35335669  2915618322800  1.08
# 2021-01-06  83300  84500  82100  82200  42089013  3506903681680 -2.03
# 2021-01-07  82800  84200  82700  82900  32644642  2726112459660  0.85
# 2021-01-08  83300  90000  83000  88800  59013307  5083939899952  7.12
# ...           ...    ...    ...    ...       ...            ...   ...
# 2022-12-23  58200  58400  57700  58100   9829407   570401785680 -1.69
# 2022-12-26  58000  58100  57700  57900   6756411   391223170600 -0.34
# 2022-12-27  58000  58400  57900  58100  10667027   620410096800  0.35
# 2022-12-28  57600  57600  56400  56600  14665410   832919426100 -2.58
# 2022-12-29  56000  56200  55300  55300  11295935   628653753150 -2.30
#
# [494 rows x 7 columns]

# %%
samsung =stock.get_market_ohlcv_by_date("20210101", "20221231", "005930")

# %%
samsung.describe()
# Out:
#                  시가            고가            저가            종가           거래량  \
# count    494.000000    494.000000    494.000000    494.000000  4.940000e+02
# mean   71657.894737  72234.210526  71043.927126  71576.315789  1.664307e+07
# std     9602.877803   9678.550744   9491.695610   9566.465781  7.871151e+06
# min    52300.000000  53600.000000  51800.000000  52600.000000  5.767902e+06
# 25%    61700.000000  62025.000000  61125.000000  61725.000000  1.210291e+07
# 50%    73000.000000  73650.000000  71750.000000  72500.000000  1.478976e+07
# 75%    80200.000000  80600.000000  79800.000000  80100.000000  1.874971e+07
# max    90300.000000  96800.000000  89500.000000  91000.000000  9.030618e+07
#
#                거래대금         등락률
# count  4.940000e+02  494.000000
# mean   1.215133e+12   -0.067308
# std    6.959809e+11    1.404773
# min    3.427809e+11   -3.700000
# 25%    8.127626e+11   -0.990000
# 50%    1.041903e+12   -0.140000
# 75%    1.379443e+12    0.660000
# ...

# %%
import matplotlib.pyplot as plt

# %%
#시가	고가	저가	종가	거래량	거래대금	등락률
plt.plot(samsung['등락률'])

# %%
plt.figure(figsize=(10, 2))
plt.rc('xtick', labelsize=8)
plt.plot(samsung['등락률'])
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.

# %%
from matplotlib import rc

# %%
import matplotlib.font_manager as fm

# %%
font_lo='C:/Windows/Fonts/BAUHS93.TTF'

# %%
font_name=fm.FontProperties(fname=font_lo).get_name()

# %%
rc('font', family=font_name)

# %%
plt.figure(figsize=(10, 2))
plt.rc('xtick', labelsize=20)
plt.plot(samsung['등락률'])
plt.show()
