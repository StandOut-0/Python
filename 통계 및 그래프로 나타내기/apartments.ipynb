# %%
import pandas as pd

# %%
apartment= pd.read_excel("D:/# 박상희/2. 실습/data/apartments_filter.xlsx")

# %%
apartment
# Out:
#                     기간  성남시 거래가
# 0  2021-01-04 00:00:52   85.014
# 1  2021-01-11 00:00:52   85.580
# 2  2021-01-18 00:00:52   86.387
# 3  2021-01-25 00:00:52   87.080
# 4  2021-02-01 00:00:52   88.025
# ..                 ...      ...
# 95 2022-11-28 00:00:52   97.395
# 96 2022-12-05 00:00:52   96.923
# 97 2022-12-12 00:00:52   96.605
# 98 2022-12-19 00:00:52   96.210
# 99 2022-12-26 00:00:52   95.887
#
# [100 rows x 2 columns]

# %%
apartment.columns
# Out:
# Index(['기간', '성남시 거래가'], dtype='object')

# %%
apartment.rename(columns={'기간':'계약년월'})
# Out:
#                   계약년월  성남시 거래가
# 0  2021-01-04 00:00:52   85.014
# 1  2021-01-11 00:00:52   85.580
# 2  2021-01-18 00:00:52   86.387
# 3  2021-01-25 00:00:52   87.080
# 4  2021-02-01 00:00:52   88.025
# ..                 ...      ...
# 95 2022-11-28 00:00:52   97.395
# 96 2022-12-05 00:00:52   96.923
# 97 2022-12-12 00:00:52   96.605
# 98 2022-12-19 00:00:52   96.210
# 99 2022-12-26 00:00:52   95.887
#
# [100 rows x 2 columns]

# %%
apartment
# Out:
#                     기간  성남시 거래가
# 0  2021-01-04 00:00:52   85.014
# 1  2021-01-11 00:00:52   85.580
# 2  2021-01-18 00:00:52   86.387
# 3  2021-01-25 00:00:52   87.080
# 4  2021-02-01 00:00:52   88.025
# ..                 ...      ...
# 95 2022-11-28 00:00:52   97.395
# 96 2022-12-05 00:00:52   96.923
# 97 2022-12-12 00:00:52   96.605
# 98 2022-12-19 00:00:52   96.210
# 99 2022-12-26 00:00:52   95.887
#
# [100 rows x 2 columns]

# %%
apartment.rename(columns={'기간':'계약년월'}, inplace=True)

# %%
apartment
# Out:
#                   계약년월  성남시 거래가
# 0  2021-01-04 00:00:52   85.014
# 1  2021-01-11 00:00:52   85.580
# 2  2021-01-18 00:00:52   86.387
# 3  2021-01-25 00:00:52   87.080
# 4  2021-02-01 00:00:52   88.025
# ..                 ...      ...
# 95 2022-11-28 00:00:52   97.395
# 96 2022-12-05 00:00:52   96.923
# 97 2022-12-12 00:00:52   96.605
# 98 2022-12-19 00:00:52   96.210
# 99 2022-12-26 00:00:52   95.887
#
# [100 rows x 2 columns]

# %%
apartment['성남시 거래가'].describe()
# Out:
# count    100.000000
# mean      97.242760
# std        4.098872
# min       85.014000
# 25%       95.371500
# 50%       99.209000
# 75%      100.241500
# max      100.885000
# Name: 성남시 거래가, dtype: float64

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(apartment['성남시 거래가'])

# %%
plt.plot(apartment['계약년월'],  apartment['성남시 거래가'],'ro')

# %%
plt.bar(apartment['계약년월'], apartment['성남시 거래가'])
# Out:
# <BarContainer object of 100 artists>

# %%
help(plt.plot)
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...
